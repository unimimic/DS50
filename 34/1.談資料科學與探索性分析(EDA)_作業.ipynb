# %% [markdown]
# ## 作業:
# 今天課程中以一個案例，說明資料分析的流程與探索性分析，是否對於課程中一開始的問題，更有想法了?!
# Q1: 哪一個問題不適合用資料科學解決?
# Q2: 以你的角度來分析，為什麼這樣的問題，較不適合用資料來解決?
# 將答案寫在論壇中，大家一起互相討論激盪。
# ![](作業圖檔.PNG)

# %%
'''
你的答案
1. 挑選 Mr./Ms. Right
2. 相較於另外兩個題目，收集的資料比較容易量化
'''
# Out:
# '\n你的答案\n'
